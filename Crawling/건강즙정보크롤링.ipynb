# %%
## 상품 url 예시
## https://search.shopping.naver.com/search/all?query=%EA%B1%B4%EA%B0%95%EC%A6%99&cat_id=&frm=NVSHATC
### query = 다음에는 내 검색어가 들어가는데, 해당 부분이 바뀌었음..


from bs4 import BeautifulSoup
from urllib.request import urlopen


url = 
params = {query : ' ',
         cat_id}
# Out:
#   File "<ipython-input-1-96197d7efde0>", line 10
#     url =
#           ^
# SyntaxError: invalid syntax

# %%
# 기타건강즙 카테고리 50007007
## 성분을 크롤링하려면 -> 네이버 쇼핑에서 url을 다 긁어오고.. 쇼핑몰 페이지마다 어떤식으로 크롤링이 되는지 확인한 뒤에
### 상품설명을 가져와야 하는데 ..? 과연 그게 잘 될까....
url = https://search.shopping.naver.com/search/all?
params = {catId : 50007007,
          frm : ,
          origQuery :  ,
          pagingIndex : , #페이지
          pagingSize : , # 몇개 출력할건지
          productSet : ,
          query : ' ',
          sort : 'review' , # 네이버랭킹 = rel , 리뷰많은 순 크롤링 = review
          timestamp : ,
          viewType : 'list'
         }    


catId=50007007&  # 
    frm=NVSHCAT&
    origQuery=%EA%B1%B4%EA%B0%95%EC%A6%99& # 검색어
    pagingIndex=1&
    pagingSize=40& # 몇개 출력할건지
    productSet=total&  
    query=%EA%B1%B4%EA%B0%95%EC%A6%99&  # 검색어
    sort=review& # 네이버랭킹 = rel , 리뷰많은 순 크롤링 = review
    timestamp=&
    viewType=list
    
    
def urlopen

# %% [markdown]
# 생각해보니까 네이버는 크롤링을 못함...
# 네이버 자체적으로 제공하는 게 아니라 모든 쇼핑몰에서 그 페이지 정보를 긁어오는 것이기 때문에
# 상품정보에 대한 설명도 다 다르고 ... 어떻게 하면 긁어올 수 있을지 생각해봐야 할 듯....

# %%
url = 
params = 

https://astg.widerplanet.com/delivery/wpc.php?
    v=1&
    ver=4.0&
    r=1&
    md=bs&
    ga=1gbeett-6a255f-2-1&
    wp_uid=2-57b92698698f816317ed62493078d47a-s1615254751.7159%7Cwindows_10%7Cchrome-l1t9a0&
    ty=Home&
    ti=42366&
    device=web&
    charset=UTF-8&
    tc=1622765392452&
    ref=https%3A%2F%2Fwww.gsshop.com%2Fshop%2Fsect%2FsectL.gs%3Fsectid%3D1462672%26lsectid%3D1462672%26lseq%3D357571%26svcid%3Dpc%26dseq%3D0&
    loc=https%3A%2F%2Fwww.gsshop.com%2Fshop%2Fsect%2FsectM.gs%3Fsectid%3D1463183%26lsectid%3D1462672%26msectid%3D1463183%26lseq%3D358308%26gsid%3DSECT-1462672-0-1

# %%
sudo apt-get install -y libssl-dev libffi-dev
# Out:
#   File "<ipython-input-3-7d7302d4114d>", line 1
#     sudo apt-get install -y libssl-dev libffi-dev
#          ^
# SyntaxError: invalid syntax

# %%
import scrapy

class BlogSpider(scrapy.Spider):
    name = 'blogspider'
    start_urls = ['https://www.zyte.com/blog/']

    def parse(self, response):
        for title in response.css('.oxy-post-title'):
            yield {'title': title.css('::text').get()}

        for next_page in response.css('a.next'):
            yield response.follow(next_page, self.parse)

# %%
scrapy runspider myspider.py
# Out:
#   File "<ipython-input-5-87bcbf0dd599>", line 1
#     scrapy runspider myspider.py
#            ^
# SyntaxError: invalid syntax

# %%
## 쿠팡 크롤링  (GS샵은 너무 어려움 ㅠㅠ http 페이지는 안 바뀌는데 내부에서 바뀌고 있어서)

import requests

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36'}
params = {
    'page' : 1
}
url = 'https://www.coupang.com/np/categories/311219'  ## 건강즙 카테고리에 해당

def getPageString(url):
    data = requests.get(url, params = params, headers = headers)
    print(data.content)
    return data.content

print(getPageString(url))
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<!--[if lte IE 7 ]><html class="lt-ie9 lt-ie8" lang="ko-KR"><![endif]-->\n<!--[if IE 8 ]><html class="lt-ie9" lang="ko-KR"><![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--><html lang="ko-KR"><!--<![endif]-->\n<head>\n    <meta charset="utf-8" />\n    <meta name="google-site-verification" content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" />\n    <meta http-equiv="x-dns-prefetch-control" content="on" />\n    <link rel="dns-prefetch" href="//cart.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupang.com" />\n    <link rel="dns-prefetch" href="//assets2.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//asset1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//private.coupang.com" />\n    <link rel="dns-prefetch" href="//img1a.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//image1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//thumbnail1.
# ...

# %%
from bs4 import BeautifulSoup

def getProducts(string):
    bsObj = BeautifulSoup(string, "html.parser")
    ul = bsObj.find("ul", {'id':'productList'})
    lis = ul.findAll('li', {'class':'baby-product renew-badge'})
    
    for item in lis:
        a = item.find("a", {'class':'baby-product-link'})
        url = a.get('href')
        print('url:', url)
        
        div_name = item.find('div', {'class':'name'})
        name = div_name.getText()
        print('name:', name)
        
        dt_image = item.find('dt', {'class':'name'})
        name = div_name.getText()
        print('name:', name)
        
        price = item.find('strong', {'class':'price-value'}).getText()
        print('price:', price)
        
    print(len(lis))
    return []

# %%
pageString = getPageString(url)
print(getProducts(pageString))
# Out:
# b'\n\n\n\n\n\n\n\n\n\n\n\n\n<!doctype html>\n<!--[if lte IE 7 ]><html class="lt-ie9 lt-ie8" lang="ko-KR"><![endif]-->\n<!--[if IE 8 ]><html class="lt-ie9" lang="ko-KR"><![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--><html lang="ko-KR"><!--<![endif]-->\n<head>\n    <meta charset="utf-8" />\n    <meta name="google-site-verification" content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" />\n    <meta http-equiv="x-dns-prefetch-control" content="on" />\n    <link rel="dns-prefetch" href="//cart.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupang.com" />\n    <link rel="dns-prefetch" href="//assets2.coupang.com" />\n    <link rel="dns-prefetch" href="//assets.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//asset1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//private.coupang.com" />\n    <link rel="dns-prefetch" href="//img1a.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//image1.coupangcdn.com" />\n    <link rel="dns-prefetch" href="//thumbnail1.
# ...
